# %% [markdown]
# <p><strong><p><ins><h1>Le robot EV3 lanceur</h1></ins></strong>
#
# <center>
# <img src="https://i.ibb.co/87ZMxnz/IMG-1580.jpg" width=50% alt="IMG-1580" border="0">
# </center>

# %% [markdown]
# <p><em>Nous allons vous presenter un robot capable de tourner, de diriger et de tirer !!!</em>

# %% [markdown]
# ## Presentation du robot
# <center>
# <img src="https://jaetate.github.io/images/show.gif" width=70% alt="IMG-1580" border="0">
# </center>

# %% [markdown]
# <h1>Presentation de ce que peut faire le robot</h1>
#
# <p><strong>Descendre et monter:</strong>
# <center>
# <img src="https://jaetate.github.io/images/up.gif" width=70% alt="IMG-1580" border="0">
# </center>
#
# <p><strong>Tourner:</strong>
# <center>
# <img src="https://jaetate.github.io/images/turn.gif" width=70% alt="IMG-1580" border="0">
# </center>
#
# <p><strong>Tirer:</strong>
#
# <center>
# <img src="https://jaetate.github.io/images/fire.gif" width=70% alt="IMG-1580" border="0">
# </center>

# %% [markdown]
# **Et tout grâce a cette télécommande 😲😲😲😲**
# <center>
# <img src="https://jaetate.github.io/images/telcommande.jpg" width=70% alt="IMG-1580" border="0">
# </center>
